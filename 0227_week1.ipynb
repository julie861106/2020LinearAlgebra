# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt

# %%
np.pi
# Out:
# 3.141592653589793

# %%
np.sqrt(4)
# Out:
# 2.0

# %%
np.sin(1)
# Out:
# 0.8414709848078965

# %%
x = np.linspace(-5, 5, 200)
y = np.sinc(x)

# %%
plt.plot(x, y)

# %%
plt.scatter(x, y)

# %%
plt.xkcd()

# %%
plt.plot(x, y)
